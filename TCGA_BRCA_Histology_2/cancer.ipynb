# %%
# !python sample_manifest.py 10

# %%
# !bash tile_slides.sh
# Out:
# mkdir: images: File exists
# cp: images/TCGA-OK-A5Q2-01Z-00-DX1.0D169898-37C6-44CA-AC87-27887123AA6F.svs and ./images/TCGA-OK-A5Q2-01Z-00-DX1.0D169898-37C6-44CA-AC87-27887123AA6F.svs are identical (not copied).
# cp: images/TCGA-A8-A09D-01Z-00-DX1.66312A8A-88BA-4B58-96DF-1A7AC39F9E4A.svs and ./images/TCGA-A8-A09D-01Z-00-DX1.66312A8A-88BA-4B58-96DF-1A7AC39F9E4A.svs are identical (not copied).
# cp: images/TCGA-B6-A0WZ-01Z-00-DX1.6CFB236E-36F5-43D6-8DE3-C4ECBD3C14C6.svs and ./images/TCGA-B6-A0WZ-01Z-00-DX1.6CFB236E-36F5-43D6-8DE3-C4ECBD3C14C6.svs are identical (not copied).
# cp: images/TCGA-A1-A0SN-01Z-00-DX1.5E9B85AE-AFB7-41DC-8A1B-BD6DA39B6540.svs and ./images/TCGA-A1-A0SN-01Z-00-DX1.5E9B85AE-AFB7-41DC-8A1B-BD6DA39B6540.svs are identical (not copied).
# cp: images/TCGA-E2-A1II-01Z-00-DX1.7F782477-0F92-4C57-8735-A1E3F95A6B94.svs and ./images/TCGA-E2-A1II-01Z-00-DX1.7F782477-0F92-4C57-8735-A1E3F95A6B94.svs are identical (not copied).
# ...

# %%
# !python /Users/VanKhai/Desktop/TCGA_BRCA_Histology/create_ludwig_training_file.py
# Out:
# a
# TCGA-EW-A1PH-01Z-00-DX1.77e0f907-fe59-4dc2-b582-6f10330a9c01
# TCGA-E2-A1L7-01Z-00-DX1.BE796CD2-2E81-44E8-8CA2-85B4D2A31B64
# TCGA-E2-A1L7-01Z-00-DX1.BE796CD2-2E81-44E8-8CA2-85B4D2A31B64
# TCGA-C8-A12Q-01Z-00-DX1.CE74E5B7-FD30-4CBE-8716-ECCF2213AAC3
# TCGA-C8-A12Q-01Z-00-DX1.CE74E5B7-FD30-4CBE-8716-ECCF2213AAC3
# TCGA-AR-A0TU-01Z-00-DX1.2CBBDDAB-C1DD-4205-A555-431542F9C069
# TCGA-AR-A0TU-01Z-00-DX1.2CBBDDAB-C1DD-4205-A555-431542F9C069
# TCGA-AO-A12D-01Z-00-DX1.BA006BAD-5C6E-4099-BC99-3888E69F506E
# TCGA-AO-A12D-01Z-00-DX1.BA006BAD-5C6E-4099-BC99-3888E69F506E
# TCGA-S3-AA15-01Z-00-DX1.A2456A4A-E6E8-4429-8F09-B997AA497BB0
# TCGA-S3-AA15-01Z-00-DX1.A2456A4A-E6E8-4429-8F09-B997AA497BB0
# TCGA-A7-A4SE-01Z-00-DX1.16BC8401-E40E-4A1A-9BD9-12735C9AE3F6
# TCGA-A7-A4SE-01Z-00-DX1.16BC8401-E40E-4A1A-9BD9-12735C9AE3F6
# TCGA-GM-A3XL-01Z-00-DX1.CCE8AA1D-9194-4E49-9546-DBF25A35847C
# TCGA-GM-A3XL-01Z-00-DX1.CCE8AA1D-9194-4E49-9546-DBF25A35847C
# ...

# %%
# !ludwig experiment --dataset er_status_all_data.csv --config config.yaml
# Out:
# /Users/VanKhai/anaconda3/lib/python3.11/site-packages/bitsandbytes/cextension.py:34: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# 'NoneType' object has no attribute 'cadam32bit_grad_fp32'
# ███████████████████████
# █ █ █ █  ▜█ █ █ █ █   █
# █ █ █ █ █ █ █ █ █ █ ███
# █ █   █ █ █ █ █ █ █ ▌ █
# █ █████ █ █ █ █ █ █ █ █
# █     █  ▟█     █ █   █
# ███████████████████████
# ludwig v0.10.3 - Experiment
#
# fatal: ambiguous argument 'HEAD': unknown revision or path not in the working tree.
# Use '--' to separate paths from revisions, like this:
# 'git <command> [<revision>...] -- [<file>...]'
#
# ╒════════════════════════╕
# │ EXPERIMENT DESCRIPTION │
# ╘════════════════════════╛
#
# ╒══════════════════╤═════════════════════════════════════════════════════════════════════╕
# ...

# %%
# !python3 -m pip install numpy
# Out:
# Python(45044) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 14.0 MB 20.6 MB/s eta 0:00:01   |█████████▏                      | 4.0 MB 3.6 MB/s eta 0:00:03
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !python3 -m pip install matplotlib
# Out:
# Python(45107) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 7.5 MB 1.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 244 kB 15.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.8 MB 18.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 103 kB 19.7 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.4 MB 21.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 66 kB 9.4 MB/s  eta 0:00:01
# ...
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !python3 -m pip install sklearn
# Out:
# Python(46166) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#     ERROR: Command errored out with exit status 1:
# ...

# %%
# !python3 -m pip install seaborn
# Out:
# Python(46181) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 294 kB 3.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.4 MB 12.0 MB/s eta 0:00:01
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/vn/1g_xbmqs4yjd1s9l02qqbk340000gp/T/pip-build-env-asztk79g/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/vn/1g_xbmqs4yjd1s9l02qqbk340000gp/T/pip-build-env-asztk79g/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
# ...

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Load JSON data
with open('results/experiment_run_4/test_statistics.json') as f:
    data = json.load(f)

# Extract ROC curve data
roc_curve = data['er_status_by_ihc']['roc_curve']
fpr = roc_curve['false_positive_rate']
tpr = roc_curve['true_positive_rate']

# Calculate AUC
auc = np.trapz(tpr, fpr)

# Plot ROC curve with AUC value
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (AUC = %0.2f)' % auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
import json

# Load JSON data
with open('/Users/VanKhai/Desktop/TCGA_BRCA_Histology/results/experiment_run_5/test_statistics.json') as f:
    data = json.load(f)

# Extract accuracy
accuracy = data['er_status_by_ihc']['accuracy']

# Print accuracy
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.4498724043369293
